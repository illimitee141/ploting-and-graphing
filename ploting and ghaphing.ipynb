# %%
# !pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print("lib")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# lib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print("lib")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# lib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print("lib")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# lib

# %%
country_population = [700,750,740,730,752,800,790]
country_population
# Out:
# [700, 750, 740, 730, 752, 800, 790]

# %%
## lineplot
country_population = [700,750,740,730,752,800,790]

plt.plot(country_population)
plt.show()

# %%
## lineplot
country_population = [700,750,740,730,752,800,790]
x_axis = [100,200,250,300,240,400,390]
plt.plot(x_axis,country_population,marker='*',ms='13',mfc='black',color='black',ls='dashed',lw='2')
plt.title("demo")
plt.xlabel('Axis-x')
plt.ylabel('country_population')
plt.show()
## mc = marker size,mfc= maker face color , ls= for graph line,lw= line width,color= for line color

# %%
country_population = [750,730,900,765,800]
country_name = ['japan','bangladesh','india','nepal','china']

plt.bar(country_name,country_population)
plt.show()

# %%
df['brand'].value_counts().keys()
# Out:
# Index(['Bajaj', 'Hero', 'Royal Enfield', 'Yamaha', 'Honda', 'Suzuki', 'TVS',
#        'KTM', 'Harley-Davidson', 'Kawasaki', 'Hyosung', 'Benelli', 'Mahindra',
#        'Triumph', 'Ducati', 'BMW', 'Jawa', 'MV', 'Indian', 'Ideal', 'Rajdoot',
#        'Yezdi', 'LML'],
#       dtype='object', name='brand')

# %%
brand_name = list(df['brand'].value_counts().keys())

# %%
no_of_count = list(df['brand'].value_counts().values)

# %%
plt.bar(brand_name,no_of_count)
# Out:
# <BarContainer object of 23 artists>

# %%
brand_name = list(df['brand'].value_counts().keys())
no_of_count = list(df['brand'].value_counts().values)
plt.bar(brand_name,no_of_count)
plt.show()

# %%
df = pd.read_csv('Used_Bikes.csv')
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             29964
# Second Owner             2564
# Third Owner               108
# Fourth Owner Or More       12
# Name: count, dtype: int64

# %%
import numpy as np

# %%
age = np.random.randint(1,100,500)
age
# Out:
# array([60, 89, 92, 34, 78, 79, 72, 20, 19,  6, 84, 97, 50, 33, 34, 83, 29,
#         8, 70, 22, 99, 60,  9, 55, 28, 37, 75, 96, 85, 53, 13,  3, 67, 40,
#        56, 18,  6, 34,  3, 33,  9, 36, 92, 81, 25, 81, 89, 24, 75, 67, 84,
#        96, 95, 72, 26, 33, 80, 67, 15, 26, 91, 33, 31, 73, 53, 33, 47, 14,
#         5, 67, 10, 69, 58, 53, 48, 40, 24, 45, 95, 69, 99, 68, 24, 29, 82,
#        83, 77, 44, 43, 24,  3, 83, 63, 67, 48, 41, 64, 38, 16, 80, 62, 48,
#        73, 65, 99, 21, 58, 18, 26, 68, 27, 40, 53, 75, 98, 53, 28, 22, 43,
#        58, 11, 67, 52, 14, 37, 72, 23, 22, 62, 78, 82, 50, 64, 35, 30, 89,
#        41, 43, 61, 50, 27, 42, 23, 13, 32, 40, 94, 31, 81, 31, 42, 83, 77,
#        43, 65, 89, 75, 90, 46, 83, 99, 90, 35, 25, 53, 51, 36, 55, 64, 83,
#        53,  2,  3, 35, 56, 30, 65, 45,  1, 60, 53, 91, 59, 10, 70, 26, 14,
#        97, 62, 99, 22, 42, 60, 19, 56,  6, 76, 79, 55, 96, 64, 99, 66, 54,
# ...

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print("lib")
# Out:
# lib

# %%
bin = [0,18,30,50,70,90,100]
plt.hist(age,bins=bin,ec='k')
plt.show()

# %%
plt.hist(age,ec='k')
plt.show()

# %%
# scatter plot

# %%
var1 = [25,41,63,96,45]

# %%
var2 = [45,63,65,25,75]
plt.scatter(var1,var2)
plt.xlabel("var-1")
plt.ylabel("var-2")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd

# %%
df= pd.read_csv('Used_Bikes.csv')
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
plt.scatter(df['kms_driven'],df['price'])
plt.show()

# %%
### pie plot

# %%
country_population = [750,730,900,765,800]
country_name = ['japan','bangladesh','india','nepal','china']

plt.pie(country_population,labels=country_name)
plt.show()

# %%
plt.pie(country_population,labels=country_name,autopct="%1.2f%%")
plt.show()

# %%
country_population = [750,730,900,765,800]
country_name = ['japan','bangladesh','india','nepal','china']
explosion = [0.2,0,0,0,1.0]
plt.pie(country_population,labels=country_name,autopct="%2.2f%%",explode=explosion,wedgeprops={'ec':'black','lw':3},shadow=True)
plt.show()

# %%
df.drop_duplicates(inplace=True)

# %%
ktm = df[df['brand']=="KTM"]
ktm.head
# Out:
# <bound method NDFrame.head of              bike_name     price        city  kms_driven         owner  age  \
# 33        KTM RC 390cc  180000.0        Pune     17700.0   First Owner  4.0
# 35      KTM Duke 200cc   70000.0      Nashik    100000.0  Second Owner  8.0
# 39    KTM RC 200cc ABS  179000.0   Bangalore      3400.0   First Owner  2.0
# 65      KTM Duke 200cc   94700.0    Baripara     32700.0   First Owner  4.0
# 83      KTM Duke 250cc  130000.0  Gandhidham     17500.0  Second Owner  4.0
# ...                ...       ...         ...         ...           ...  ...
# 9070      KTM RC 200cc  140000.0  Berhampore      2600.0   First Owner  6.0
# 9195    KTM Duke 200cc   70000.0       Thane     49347.0   First Owner  9.0
# 9255    KTM Duke 125cc  135000.0   Bangalore      1050.0   First Owner  3.0
# 9282    KTM Duke 390cc  139100.0       Delhi     25500.0   First Owner  5.0
# 9348    KTM Duke 390cc  195000.0      Mumbai      4568.0   First Owner  4.0
#
#       power brand
# ...

# %%
ktm['price'].min()
# Out:
# np.float64(55000.0)

# %%
ktm['price'].max()
# Out:
# np.float64(860000.0)

# %%
ktm['price'].median()
# Out:
# np.float64(142600.0)

# %%
plt.boxplot(ktm['price'])
plt.show()

# %%
ktm.shape
# Out:
# (375, 8)

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
